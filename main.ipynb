# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# d:\Projects\FinAgent\.venv\Scripts\python.exe
# 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:39:58) [MSC v.1943 64 bit (AMD64)]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
pip install yfinance
# Out:
# ...
#   Using cached yfinance-1.5.1-py2.py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached peewee-4.1.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# ...
# Using cached yfinance-1.5.1-py2.py3-none-any.whl (144 kB)
# Using cached curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
# Using cached multitasking-0.0.13-py3-none-any.whl (16 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.9 MB 2.3 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.9 MB 2.1 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.9 MB 2.2 MB/s eta 0:00:04
# ...

# %%
import yfinance as yf   
df = yf.download('AAPL', start='2020-01-01', end='2021-01-01') 
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.333862  72.394070  71.091169  71.344039  135480400
# 2020-01-03  71.630661  72.389280  71.406689  71.563228  146322800
# 2020-01-06  72.201408  72.239942  70.503546  70.754014  118387200
# 2020-01-07  71.861847  72.466330  71.642689  72.211049  108872000
# 2020-01-08  73.017838  73.318877  71.565621  71.565621  132079200

# %%
stocks = yf.download(["APPL","MSFT","GOOGL","NVDA"],start = "2023-01-01")
# Out:
# [                       0%                       ]$APPL: possibly delisted; no price data found  (1d 2023-01-01 -> 2026-07-05)
# [*********************100%***********************]  4 of 4 completed
#
# 1 Failed download:
# ['APPL']: possibly delisted; no price data found  (1d 2023-01-01 -> 2026-07-05)

# %%
apple = yf.Ticker("AAPL")
info = apple.info
print(info["longName"])
print(info["sector"])
print(info["industry"])
# Out:
# Apple Inc.
# Technology
# Consumer Electronics

# %%
print(apple.financials)
# Out:
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.560000e-01
# Normalized EBITDA                                   1.447480e+11
# Net Income From Continuing Operation Net Minori...  1.120100e+11
# Reconciled Depreciation                             1.169800e+10
# Reconciled Cost Of Revenue                          2.209600e+11
# EBITDA                                              1.447480e+11
# EBIT                                                1.330500e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   1.120100e+11
# Net Income From Continuing And Discontinued Ope...  1.120100e+11
# ...

# %%
print(apple.balance_sheet)
print(apple.cashflow)
history = apple.history(period="5y")
print(history.head())
# Out:
#                                                     2025-09-30    2024-09-30  \
# Treasury Shares Number                                     NaN           NaN
# Ordinary Shares Number                            1.477326e+10  1.511679e+10
# Share Issued                                      1.477326e+10  1.511679e+10
# Net Debt                                          6.272300e+10  7.668600e+10
# Total Debt                                        9.865700e+10  1.066290e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  5.469700e+10  6.517100e+10
# Other Short Term Investments                      1.876300e+10  3.522800e+10
# Cash And Cash Equivalents                         3.593400e+10  2.994300e+10
# Cash Equivalents                                  7.667000e+09  2.744000e+09
# Cash Financial                                    2.826700e+10  2.719900e+10
#
# ...

# %%
apple.history(
    period="5d",
    interval="1m"
)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2026-06-26 09:30:00-04:00  275.000000  275.429993  274.209991  275.214996
# 2026-06-26 09:31:00-04:00  275.214996  277.510010  275.170013  277.225006
# 2026-06-26 09:32:00-04:00  277.225006  278.000000  276.690002  276.769989
# 2026-06-26 09:33:00-04:00  276.779999  276.779999  275.970093  276.214996
# 2026-06-26 09:34:00-04:00  276.214996  276.989899  275.769989  276.929993
# ...                               ...         ...         ...         ...
# 2026-07-02 15:55:00-04:00  308.040009  309.250000  308.040009  309.149994
# 2026-07-02 15:56:00-04:00  309.179993  309.279999  308.910004  309.149994
# 2026-07-02 15:57:00-04:00  309.149994  309.420013  308.950012  309.089996
# 2026-07-02 15:58:00-04:00  309.100006  309.230011  308.709991  308.744995
# 2026-07-02 15:59:00-04:00  308.750000  308.959991  308.100006  308.220001
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
apple.splits
# Out:
# Date
# 1987-06-16 09:30:00-04:00    2.0
# 2000-06-21 09:30:00-04:00    2.0
# 2005-02-28 09:30:00-05:00    2.0
# 2014-06-09 09:30:00-04:00    7.0
# 2020-08-31 09:30:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
# !pip install matplotlib pandas
# Out:
# ...
#   Using cached pillow-12.3.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 2.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.3 MB 2.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.3 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/9.3 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/9.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.3 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.3 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/9.3 MB 2.1 MB/s eta 0:00:03
# ...

# %%
import matplotlib.pyplot as plt

df = yf.download("AAPL", period="5y")

df["Close"].plot(figsize=(10,5))
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
